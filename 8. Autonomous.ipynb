# %%
from pylab import *
from numpy import ma
# %matplotlib inline

# %%
x, y = meshgrid(arange(-1.5,1.5,0.1), arange(-1.5,1.5,0.1))

# %%
xdot = -x -x * y**2
ydot = -y -y * x**2

# %%
quiver(xdot, ydot)
